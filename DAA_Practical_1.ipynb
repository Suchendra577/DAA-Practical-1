# %% [markdown]
# ## Lab 1

# %% [markdown]
# Bubble Sort

# %%
import time

def bubble_sort(arr):
    n = len(arr)
    for i in range(n - 1):
        # Last i elements are already in place
        for j in range(0, n - i - 1):
            # Traverse the array from 0 to n-i-1
            # Swap if the element found is greater than the next element
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
    return arr

# Get user input for the list
user_input = input("Enter numbers separated by spaces for Bubble Sort: ")
try:
    my_list_bubble = list(map(int, user_input.split()))
except ValueError:
    print("Invalid input. Please enter numbers only.")
    my_list_bubble = []

if my_list_bubble:
    print(f"Original list: {my_list_bubble}")

    # Measure execution time
    start_time = time.time()
    sorted_list_bubble = bubble_sort(list(my_list_bubble)) # Use a copy to avoid modifying original list before sort
    end_time = time.time()
    execution_time = end_time - start_time

    print(f"Sorted list (Bubble Sort): {sorted_list_bubble}")
    print(f"Execution Time (Bubble Sort): {execution_time:.6f} seconds")
    print("Time Complexity (Bubble Sort): O(N^2) in average/worst case, O(N) in best case")
    print("Space Complexity (Bubble Sort): O(1) auxiliary space")
else:
    print("No valid numbers entered for Bubble Sort.")
# Out:
# Enter numbers separated by spaces for Bubble Sort: 13 24 10 17 21
# Original list: [13, 24, 10, 17, 21]
# Sorted list (Bubble Sort): [10, 13, 17, 21, 24]
# Execution Time (Bubble Sort): 0.000011 seconds
# Time Complexity (Bubble Sort): O(N^2) in average/worst case, O(N) in best case
# Space Complexity (Bubble Sort): O(1) auxiliary space

# %% [markdown]
# Selection Sort

# %%
import time

def selection_sort(arr):
    n = len(arr)
    for i in range(n):
        # Find the minimum element in remaining unsorted array
        min_idx = i
        for j in range(i + 1, n):
            if arr[j] < arr[min_idx]:
                min_idx = j

        # Swap the found minimum element with the first element
        arr[i], arr[min_idx] = arr[min_idx], arr[i]
    return arr

# Get user input for the list
user_input = input("Enter numbers separated by spaces for Selection Sort: ")
try:
    my_list_selection = list(map(int, user_input.split()))
except ValueError:
    print("Invalid input. Please enter numbers only.")
    my_list_selection = []

if my_list_selection:
    print(f"Original list: {my_list_selection}")

    # Measure execution time
    start_time = time.time()
    sorted_list_selection = selection_sort(list(my_list_selection)) # Use a copy to avoid modifying original list before sort
    end_time = time.time()
    execution_time = end_time - start_time

    print(f"Sorted list (Selection Sort): {sorted_list_selection}")
    print(f"Execution Time (Selection Sort): {execution_time:.6f} seconds")
    print("Time Complexity (Selection Sort): O(N^2) in all cases")
    print("Space Complexity (Selection Sort): O(1) auxiliary space")
else:
    print("No valid numbers entered for Selection Sort.")
# Out:
# Enter numbers separated by spaces for Selection Sort: 13 25 11 24 16
# Original list: [13, 25, 11, 24, 16]
# Sorted list (Selection Sort): [11, 13, 16, 24, 25]
# Execution Time (Selection Sort): 0.000013 seconds
# Time Complexity (Selection Sort): O(N^2) in all cases
# Space Complexity (Selection Sort): O(1) auxiliary space

# %% [markdown]
# Merge Sort

# %%
import time

def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr) // 2  # Finding the mid of the array
        L = arr[:mid]  # Dividing the array elements into 2 halves
        R = arr[mid:]

        merge_sort(L)  # Sorting the first half
        merge_sort(R)  # Sorting the second half

        i = j = k = 0

        # Copy data to temp arrays L[] and R[]
        while i < len(L) and j < len(R):
            if L[i] < R[j]:
                arr[k] = L[i]
                i += 1
            else:
                arr[k] = R[j]
                j += 1
            k += 1

        # Checking if any element was left
        while i < len(L):
            arr[k] = L[i]
            i += 1
            k += 1

        while j < len(R):
            arr[k] = R[j]
            j += 1
            k += 1
    return arr

# Get user input for the list
user_input = input("Enter numbers separated by spaces for Merge Sort: ")
try:
    my_list_merge = list(map(int, user_input.split()))
except ValueError:
    print("Invalid input. Please enter numbers only.")
    my_list_merge = []

if my_list_merge:
    print(f"Original list: {my_list_merge}")

    # Measure execution time
    start_time = time.time()
    sorted_list_merge = merge_sort(list(my_list_merge)) # Use a copy to avoid modifying original list before sort
    end_time = time.time()
    execution_time = end_time - start_time

    print(f"Sorted list (Merge Sort): {sorted_list_merge}")
    print(f"Execution Time (Merge Sort): {execution_time:.6f} seconds")
    print("Time Complexity (Merge Sort): O(N log N) in all cases")
    print("Space Complexity (Merge Sort): O(N) auxiliary space")
else:
    print("No valid numbers entered for Merge Sort.")
# Out:
# Enter numbers separated by spaces for Merge Sort: 13 25 11 24 16
# Original list: [13, 25, 11, 24, 16]
# Sorted list (Merge Sort): [11, 13, 16, 24, 25]
# Execution Time (Merge Sort): 0.000019 seconds
# Time Complexity (Merge Sort): O(N log N) in all cases
# Space Complexity (Merge Sort): O(N) auxiliary space

# %% [markdown]
# Quick Sort

# %%
import time

def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    else:
        pivot = arr[len(arr) // 2]
        left = [x for x in arr if x < pivot]
        middle = [x for x in arr if x == pivot]
        right = [x for x in arr if x > pivot]
        return quick_sort(left) + middle + quick_sort(right)

# Get user input for the list
user_input = input("Enter numbers separated by spaces for Quick Sort: ")
try:
    my_list_quick = list(map(int, user_input.split()))
except ValueError:
    print("Invalid input. Please enter numbers only.")
    my_list_quick = []

if my_list_quick:
    print(f"Original list: {my_list_quick}")

    # Measure execution time
    start_time = time.time()
    sorted_list_quick = quick_sort(list(my_list_quick)) # Use a copy to avoid modifying original list before sort
    end_time = time.time()
    execution_time = end_time - start_time

    print(f"Sorted list (Quick Sort): {sorted_list_quick}")
    print(f"Execution Time (Quick Sort): {execution_time:.6f} seconds")
    print("Time Complexity (Quick Sort): O(N log N) on average, O(N^2) in worst case")
    print("Space Complexity (Quick Sort): O(log N) on average, O(N) in worst case (due to recursion stack)")
else:
    print("No valid numbers entered for Quick Sort.")
# Out:
# Enter numbers separated by spaces for Quick Sort: 13 25 11 24 16
# Original list: [13, 25, 11, 24, 16]
# Sorted list (Quick Sort): [11, 13, 16, 24, 25]
# Execution Time (Quick Sort): 0.000019 seconds
# Time Complexity (Quick Sort): O(N log N) on average, O(N^2) in worst case
# Space Complexity (Quick Sort): O(log N) on average, O(N) in worst case (due to recursion stack)

# %% [markdown]
# ## Lab 2
